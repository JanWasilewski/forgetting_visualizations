# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

with open(f'animations/test11.pkl', 'rb') as file:
        data_anim = pickle.load(file)

# %%
accs = np.array([data_anim[i][2] + [0] * (5 - len(data_anim[i][2])) for i in range(len(data_anim))]).transpose()

# %%
accs.shape
# Out:
# (5, 4700)

# %%
for i in range(5):
    plt.plot(accs[i])
